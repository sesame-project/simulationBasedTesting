# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
import sys

# %%
timebased_res = pd.read_csv("locomotec-res-timebased-python", delim_whitespace=True)
timebased_res
# Out:
#                               Testing  uvMissSurface  uvExcessHuman
# 0   Test:Test_028_14_11_2022_11_42_37           0.00           0.00  \
# 1   Test:Test_360_15_11_2022_03_58_45           9.72           0.08
# 2   Test:Test_509_15_11_2022_12_26_41          11.10           0.00
# 3   Test:Test_939_16_11_2022_11_55_44           0.00           0.00
# 4   Test:Test_944_16_11_2022_13_05_58           0.00          15.54
# 5   Test:Test_985_16_11_2022_15_27_28           0.00          10.96
# 6   Test:Test_780_16_11_2022_02_44_56           7.60           0.54
# 7   Test:Test_856_16_11_2022_07_17_56           7.00           7.30
# 8   Test:Test_723_16_11_2022_00_30_03           2.15           8.91
# 9   Test:Test_837_16_11_2022_06_09_15           6.75           7.48
# 10  Test:Test_893_16_11_2022_09_36_12           4.54          12.44
# 11  Test:Test_949_16_11_2022_13_05_58           0.58          11.66
# 12  Test:Test_872_16_11_2022_08_26_55           2.87           5.89
# 13  Test:Test_994_16_11_2022_15_27_28           3.17           0.00
# 14  Test:Test_979_16_11_2022_14_16_31           6.13           4.30
# 15  Test:Test_537_15_11_2022_13_31_11           2.66          12.82
# 16  Test:Test_813_16_11_2022_05_00_49           9.10           1.02
# 17  Test:Test_878_16_11_2022_08_26_55           5.28           1.72
# 18  Test:Test_993_16_11_2022_15_27_28           2.99           2.91
# 19  Test:Test_762_16_11_2022_02_44_56           6.20           4.05
#
#     fuzzOpTimes  Graphtag                                          FuzzingOp
# 0          0.08         0  1:personDetectionDelay([2.43-4.10])FixedTimeAc...
# 1        522.88         3  5:personDetectionPacketLossAll([0.00-0.00])Fix...
# 2        146.46         0  1:personDetectionPacketLossAll([0.00-0.00])Fix...
# 3          0.08         2  1:personDetectionDelay([2.43-4.10])FixedTimeAc...
# 4        213.78         0  3:distortPersonSector([0.72-1.31])FixedTimeAct...
# 5        105.22         0  3:personDetectionDelay([2.43-4.10])FixedTimeAc...
# 6        264.50         0  6:personDetectionPacketLossAll([0.00-0.00])Fix...
# 7        372.98         0  6:distortPersonSector([0.75-1.08])FixedTimeAct...
# 8        159.14         0  6:distortPersonSector([1.02-1.13])FixedTimeAct...
# 9        447.02         0  7:personDetectionPacketLossAll([0.00-0.00])Fix...
# 10       320.98         0  8:personDetectionPacketLossAll([0.00-0.00])Fix...
# 11       196.26         0  6:distortPersonSector([-0.65-1.16])FixedTimeAc...
# 12        86.60         0  3:distortPersonSector([0.54-0.93])FixedTimeAct...
# 13        42.78         1  2:personDetectionPacketLossAll([0.00-0.00])Fix...
# 14       307.49         0  5:personDetectionDelay([2.43-4.10])FixedTimeAc...
# 15       211.15         0  4:distortPersonSector([-1.10-0.68])FixedTimeAc...
# 16       316.63         0  7:personDetectionPacketLossAll([0.00-0.00])Fix...
# 17       138.41         0  4:personDetectionPacketLossAll([0.00-0.00])Fix...
# 18       129.35         0  4:distortPersonSector([0.54-0.93])FixedTimeAct...
# 19       161.38         0  3:personDetectionPacketLossAll([0.00-0.00])Fix...

# %%
condbased_res = pd.read_csv("locomotec-res-condfuzz-python", delim_whitespace=True)
condbased_res
# Out:
#                               Testing  uvMissSurface  uvDisinfectionS1
# 0   Test:Test_455_19_11_2022_18_21_08           4.72             10.88  \
# 1   Test:Test_774_20_11_2022_12_24_28           4.74             10.67
# 2   Test:Test_812_20_11_2022_14_46_18           1.49             21.80
# 3   Test:Test_957_20_11_2022_23_16_10          11.10              0.00
# 4   Test:Test_992_21_11_2022_01_45_56           0.00             20.08
# 5   Test:Test_603_20_11_2022_02_38_16           5.83             13.14
# 6   Test:Test_001_18_11_2022_19_05_10          10.80              0.02
# 7   Test:Test_999_21_11_2022_01_45_56           2.16             19.33
# 8   Test:Test_785_20_11_2022_12_59_49           3.01             12.27
# 9   Test:Test_822_20_11_2022_15_22_01           2.82             21.05
# 10  Test:Test_905_20_11_2022_20_11_33           0.00             20.26
# 11  Test:Test_805_20_11_2022_14_10_43           5.63             13.07
# 12  Test:Test_864_20_11_2022_17_45_55           3.08             20.50
# 13  Test:Test_832_20_11_2022_15_57_50           0.00             21.66
# 14  Test:Test_963_20_11_2022_23_53_24           2.45             19.96
# 15  Test:Test_883_20_11_2022_18_58_31           2.83             11.64
# 16  Test:Test_958_20_11_2022_23_16_10           1.95             19.97
# 17  Test:Test_631_20_11_2022_04_19_51           2.04             19.81
# 18  Test:Test_877_20_11_2022_18_22_09           0.00             22.29
# 19  Test:Test_983_21_11_2022_01_08_19           4.61             12.25
#
#     uvDisinfectionS2  uvDisinfectionS3  uvExposureForHuman_p1  uvExcessHuman
# 0               1.62              1.06                  18.68          15.68  \
# 1               1.59              1.07                  18.65          15.65
# 2               2.19             12.89                   0.24           0.00
# 3               0.00              0.00                   0.00           0.00
# 4               6.64              7.69                  15.44          12.44
# 5               0.86              0.71                  10.41           7.41
# 6               0.00              0.28                   0.00           0.00
# 7               1.54              7.36                  14.93          11.93
# 8               0.69             12.61                   4.76           1.76
# 9               0.88             11.58                   7.39           4.39
# 10              6.03              8.64                  16.92          13.92
# 11              0.91              0.85                  10.92           7.92
# 12              0.62             12.88                   0.16           0.00
# 13              5.92             11.43                   9.27           6.27
# 14              1.25              8.33                  12.85           9.85
# 15              6.27              0.87                  17.83          14.83
# 16              1.75              8.50                  13.31          10.31
# 17              1.66              9.01                   8.25           5.25
# 18              5.86             11.34                  11.15           8.15
# 19              0.32              2.46                   0.09           0.00
#
#     fuzzOpTimes                                          FuzzingOp
# 0        266.67  2:distortPersonSector([0.59-1.09])ConditionBas...
# 1        266.85  2:distortPersonSector([1.34-1.45])ConditionBas...
# 2          0.00                                                 0:
# 3        124.89  2:distortPersonSector([-1.30--1.28])ConditionB...
# 4        102.49  1:distortPersonSector([1.47-1.49])ConditionBas...
# 5        200.92  2:personDetectionPacketLossAll([0.00-0.00])Con...
# 6         81.07  2:personDetectionPacketLoss([0.42-0.63])Condit...
# 7        154.13  2:personDetectionPacketLossAll([0.00-0.00])Con...
# 8        143.14  2:distortPersonSector([-1.30--1.28])ConditionB...
# 9         58.03  2:distortPersonSector([1.16-1.35])ConditionBas...
# 10       114.91  1:distortPersonSector([1.41-1.45])ConditionBas...
# 11       197.26  2:personDetectionPacketLossAll([0.00-0.00])Con...
# 12        20.84  1:personDetectionPacketLossAll([0.00-0.00])Con...
# 13        36.19  1:distortPersonSector([1.47-1.49])ConditionBas...
# 14       135.17  2:distortPersonSector([1.16-1.35])ConditionBas...
# 15       245.90  2:distortPersonSector([1.34-1.45])ConditionBas...
# 16       114.16  2:distortPersonSector([1.16-1.35])ConditionBas...
# 17        99.92  2:distortPersonSector([0.90-1.18])ConditionBas...
# 18        67.21  1:distortPersonSector([1.47-1.50])ConditionBas...
# 19        63.65  1:personDetectionPacketLossAll([0.00-0.00])Con...

# %%
def plot_3d_resultset_stalks(frontCSVFile, secondCSVFile, graph_title, savefigFilename):
    df = pd.read_csv(frontCSVFile, delim_whitespace=True)
    if not (secondCSVFile is None):
         df2 = pd.read_csv(secondCSVFile, delim_whitespace=True)
    
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')    
    ax.view_init(40, 200)
    (markerline, stemlines, baseline) = ax.stem(df["uvMissSurface"], df["uvExcessHuman"], df["fuzzOpTimes"])
    
    if not (secondCSVFile is None):
        (markerline2, stemlines2, baseline2) = ax.stem(df2["uvMissSurface"], df2["uvExcessHuman"], df2["fuzzOpTimes"])
        plt.setp(baseline2, visible=False)
        plt.setp(markerline2, color="green")
        plt.setp(stemlines2, color="green")
        
    plt.setp(baseline, visible=False)

    ax.set_xlabel("UVC Disinfection\n Surface Miss")
    ax.set_ylabel("UVC Excess\n Human Exposure")
    ax.set_zlabel("Fuzzing Operation Times")
    ax.set_title(graph_title)
    plt.tight_layout()
    plt.savefig(savefigFilename)
    plt.show()

# %%
def plot_3d_resultset(frontCSVFile, secondCSVFile, graph_title, savefigFilename):
    df = pd.read_csv(frontCSVFile, delim_whitespace=True)
    if not (secondCSVFile is None):
         df2 = pd.read_csv(secondCSVFile, delim_whitespace=True)
    
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')    
    ax.view_init(40, 200)
    ax.scatter(df["uvMissSurface"], df["uvExcessHuman"], df["fuzzOpTimes"])
    
    if not (secondCSVFile is None):
        ax.scatter(df2["uvMissSurface"], df2["uvExcessHuman"], df2["fuzzOpTimes"], color="green")

    ax.set_xlabel("UVC Disinfection\n Surface Miss")
    ax.set_ylabel("UVC Excess\n Human Exposure")
    ax.set_zlabel("Fuzzing Operation Times")
    ax.set_title(graph_title)
    plt.tight_layout()
    plt.savefig(savefigFilename)
    plt.show()

# %%
plot_3d_resultset("locomotec-res-timebased-python", None, "Time-based fuzzing Pareto front", "rq1-timebased-3d-pareto.pdf")

# %%
plot_3d_resultset("locomotec-res-timebased-python", "locomotec-res-condfuzz-python", "Condition-based fuzzing Pareto front", "rq2-condbased-3d-pareto.pdf")

# %%
# Plot the times for condition-based fuzzing for both condition-based and time-based fuzzing
timebased_times = timebased_res["fuzzOpTimes"]

bins = np.linspace(0, 1000, 30)
plt.hist(timebased_times, bins, alpha=0.5, label='Timebased')
plt.title("Distribution of fuzzing times for both time-based and condition-based")
plt.legend(loc='upper right')
plt.show()

# %%
# Plot the times for condition-based fuzzing for both condition-based and time-based fuzzing
condbased_times = timebased_res["fuzzOpTimes"]

bins = np.linspace(0, 1000, 30)
plt.hist(condbased_times, bins, alpha=0.5, label='Timebased')
plt.title("Distribution of fuzzing times for both time-based and condition-based")
plt.legend(loc='upper right')
plt.show()

# %%
# Plot the times for condition-based fuzzing for both condition-based and time-based fuzzing
timebased_times = timebased_res["fuzzOpTimes"]
condbased_times = condbased_res["fuzzOpTimes"]

bins = np.linspace(0, 1000, 30)
plt.hist(timebased_times, bins, alpha=0.5, label='Timebased')
plt.hist(condbased_times, bins, alpha=0.5, label='Condition-based')
plt.title("Distribution of total fuzzing times in the final front for both time-based and condition-based")
plt.legend(loc='upper right')
plt.show()

# %%
fig, axes = plt.subplots(2, 1)
# Plot the times for condition-based fuzzing for both condition-based and time-based fuzzing
timebased_times = timebased_res["fuzzOpTimes"]
condbased_times = condbased_res["fuzzOpTimes"]

plt.suptitle("Distribution of fuzzing times for\n both time-based and condition-based variants")
bins = np.linspace(0, 600, 20)
axes[0].hist(timebased_times, bins, alpha=1.0, label='Time-based')
axes[0].legend(loc='upper right')
#axes[0].set(xlabel="Total fuzzing operation time (s)")

axes[1].hist(condbased_times, bins, alpha=1.0, color="green", label='Condition-based')
axes[1].legend(loc='upper right')
axes[1].set(xlabel="Total fuzzing operation time (s)")
plt.savefig("rq2-fuzzing-times.pdf")
plt.show()
