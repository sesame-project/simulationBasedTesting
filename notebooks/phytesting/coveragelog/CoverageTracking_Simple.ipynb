# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tracked = pd.read_csv("coverageTracking.log")
boosted = pd.read_csv("coverageWithBoosting.log")
tracked
# Out:
#     evaluations  coverageProp
# 0            10      0.064815
# 1            20      0.120370
# 2            30      0.157407
# 3            40      0.185185
# 4            50      0.222222
# 5            60      0.222222
# 6            70      0.240741
# 7            80      0.259259
# 8            90      0.296296
# 9           100      0.314815
# 10          110      0.333333
# 11          120      0.333333
# 12          130      0.361111
# 13          140      0.379630
# 14          150      0.388889
# 15          160      0.407407
# 16          170      0.416667
# 17          180      0.425926
# 18          190      0.435185
# 19          200      0.435185
# 20          210      0.444444
# 21          220      0.453704
# 22          230      0.462963
# 23          240      0.472222
# 24          250      0.472222
# 25          260      0.490741
# 26          270      0.490741
# 27          280      0.490741
# 28          290      0.490741
# 29          300      0.500000

# %%
boosted
# Out:
#     evaluations  coverageProp
# 0            10      0.074074
# 1            20      0.138889
# 2            30      0.166667
# 3            40      0.259259
# 4            50      0.296296
# 5            60      0.333333
# 6            70      0.361111
# 7            80      0.379630
# 8            90      0.407407
# 9           100      0.435185
# 10          110      0.444444
# 11          120      0.444444
# 12          130      0.453704
# 13          140      0.453704
# 14          150      0.472222
# 15          160      0.472222
# 16          170      0.481481
# 17          180      0.481481
# 18          190      0.481481
# 19          200      0.500000

# %%
plt.plot(tracked["evaluations"], tracked["coverageProp"])
plt.plot(boosted["evaluations"], boosted["coverageProp"])
plt.legend(["Coverage tracking", "Coverage boosting by mutation"])
plt.xlabel("Evaluations")
plt.ylabel("Coverage proportion - target 0.5")
plt.savefig("coverage_comparison.png")
